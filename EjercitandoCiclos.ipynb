# %% [markdown]
# <a href="https://colab.research.google.com/github/nancyB3a/FPY1101_2026/blob/main/EjercitandoCiclos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejercicios par resolver con ciclo FOR

# %% [markdown]
# **Ejercicio 1:**
# Ingresar por teclado 5 números enteros, luego debe indicar:
#
# *   Cuántos números son mayores a cero
# *   Cuántos números son menores a cero
# *   Cuántos números son iguales a cero

# %% [markdown]
# **Ejercicio 2:**
# Ingrese por teclado 10 letras, indique cuántas de ellas son vocales y cuántas
# son consonantes.

# %% [markdown]
# **Ejercicio 3:**
# Ingrese un número entero mayor a cero por teclado e indique si es o no “Primo”.

# %% [markdown]
# **Ejercicio 4:**
# Ingrese un número entero mayor a cero por teclado e indique si es o no “Perfecto”.

# %% [markdown]
# ---

# %% [markdown]
# # Ejercicios para resolver con ciclo WHILE

# %% [markdown]
# **Ejercicio 1:**
# Calcular el factorial de un número ingresado por teclado

# %% [markdown]
# **Ejercicio 2:**
# Ingrese por teclado números enteros positivos hasta que el usuario no quiera ingresar mas, súmelos y muestre el resultado de la suma.

# %% [markdown]
# **Ejercicio 3:**
# Solicite un valor numérico por pantalla, el valor debe ser impar, por lo
# que cada vez que se ingrese un número par, el sistema deberá
# mostrar un mensaje de error y volver a solicitar la variable, para este
# ejercicio use un ciclo de condición y el operador aritmético ‘%’, al
# ingresar el número impar el sistema deberá mostrar por una salida de
# pantalla el valor multiplicado por 4. El ciclo se debe acabar cuando el usuario ingrese un 0 (CERO).

# %% [markdown]
# **Ejercicio 4:**
# Ingrese por teclado un número entero positivo entre 103 y 987,
# luego genere un proceso que permita invertir el número,
# aplicando las 4 operaciones matemáticas básicas (suma, resta,
# multiplicación y división). Finalmente, muestre el resultado.
#
# **Ejemplo:**
#
#
# ![image.png](data:image/png;base64,...)
